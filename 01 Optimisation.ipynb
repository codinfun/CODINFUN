# %% [markdown]
# <a href="https://colab.research.google.com/github/codinfun/CODINFUN/blob/master/01%20Optimisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import numpy as np
from matplotlib import cm
import time
from numba import jit

size = 500
Afficheur = None


def Affiche(TBL):
  global Afficheur
  K = Image.fromarray((cm.gist_ncar(board)*255.0).astype('uint8'),'RGBA')
  if Afficheur == None :
    Afficheur = display(K, display_id=True)
  else:
    Afficheur.update(K)

@jit(nopython=True)
def compute():
  dx = np.random.random()/size
  dy = np.random.random()/size
  T = np.empty((size,size))
  for x in range(size):
    for y in range(size):
      T[x][y] = dx * x + dy  *y
  return T

 

for i in range(200):    
    time.sleep(1)
    board = compute()
    Affiche(board)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x500 at 0x7FC177DB83C8>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-569b96488bf7> in <module>()
#      30
#      31 for i in range(200):
# ---> 32     time.sleep(1)
#      33     board = compute()
#      34     Affiche(board)
#
# KeyboardInterrupt:

# %% [markdown]
# test
